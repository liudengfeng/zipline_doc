# %%
from zipline.pipeline import Pipeline
from zipline.research import run_pipeline,symbols,symbol
from zipline.pipeline.fundamentals import Fundamentals

# %% [markdown]
# # 列信息

# %%
Fundamentals.info.columns
# Out:
# frozenset({infoes<CN>.A001::bool,
#            infoes<CN>.A002::bool,
#            infoes<CN>.A003::bool,
#            infoes<CN>.A004::bool,
#            infoes<CN>.A005::bool,
#            infoes<CN>.A006::bool,
#            infoes<CN>.A007::bool,
#            infoes<CN>.A008::bool,
#            infoes<CN>.A009::bool,
#            infoes<CN>.A010::bool,
#            infoes<CN>.A011::bool,
#            infoes<CN>.A012::bool,
#            infoes<CN>.A013::bool,
#            infoes<CN>.A014::bool,
#            infoes<CN>.A015::bool,
#            infoes<CN>.A016::bool,
#            infoes<CN>.A017::bool,
#            infoes<CN>.A018::bool,
#            infoes<CN>.A019::bool,
#            infoes<CN>.A020::bool,
#            infoes<CN>.A021::bool,
#            infoes<CN>.A022::bool,
#            infoes<CN>.A023::bool,
#            infoes<CN>.A024::bool,
#            infoes<CN>.A025::bool,
#            infoes<CN>.A026::bool,
#            infoes<CN>.A027::bool,
#            infoes<CN>.A028::bool,
#            infoes<CN>.A029::bool,
#            infoes<CN>.A030::bool,
#            infoes<CN>.A031::bool,
#            infoes<CN>.A032::bool,
#            infoes<CN>.A033::bool,
#            infoes<CN>.A034::bool,
#            infoes<CN>.A035::bool,
#            infoes<CN>.A036::bool,
#            infoes<CN>.A037::bool,
#            infoes<CN>.A038::bool,
#            infoes<CN>.A039::bool,
#            infoes<CN>.A040::bool,
#            infoes<CN>.A041::bool,
#            infoes<CN>.A042::bool,
#            infoes<CN>.A043::bool,
#            infoes<CN>.A044::bool,
#            infoes<CN>.A045::bool,
#            infoes<CN>.A046::bool,
#            infoes<CN>.A047::bool,
#            infoes<CN>.A048::bool,
#            infoes<CN>.A049::bool,
#            infoes<CN>.A050::bool,
#            infoes<CN>.A051::bool,
#            infoes<CN>.A052::bool,
#            infoes<CN>.A053::bool,
#            infoes<CN>.A054::bool,
#            infoes<CN>.A055::bool,
#            infoes<CN>.A056::bool,
#            infoes<CN>.A057::bool,
#            infoes<CN>.A058::bool,
#            infoes<CN>.A059::bool,
#            infoes<CN>.A060::bool,
#            infoes<CN>.A061::bool,
#            infoes<CN>.A062::bool,
#            infoes<CN>.A063::bool,
#            infoes<CN>.A064::bool,
#            infoes<CN>.A065::bool,
#            infoes<CN>.A066::bool,
#            infoes<CN>.A067::bool,
#            infoes<CN>.A068::bool,
#            infoes<CN>.A069::bool,
#            infoes<CN>.A070::bool,
#            infoes<CN>.A071::bool,
#            infoes<CN>.A072::bool,
#            infoes<CN>.A073::bool,
#            infoes<CN>.A074::bool,
#            infoes<CN>.A075::bool,
#            infoes<CN>.A076::bool,
#            infoes<CN>.A077::bool,
#            infoes<CN>.A078::bool,
#            infoes<CN>.A079::bool,
#            infoes<CN>.A080::bool,
#            infoes<CN>.A081::bool,
#            infoes<CN>.A082::bool,
#            infoes<CN>.A083::bool,
#            infoes<CN>.A084::bool,
#            infoes<CN>.A085::bool,
#            infoes<CN>.A086::bool,
#            infoes<CN>.A087::bool,
#            infoes<CN>.A088::bool,
#            infoes<CN>.A089::bool,
#            infoes<CN>.A090::bool,
#            infoes<CN>.A091::bool,
#            infoes<CN>.A092::bool,
#            infoes<CN>.A093::bool,
#            infoes<CN>.A094::bool,
#            infoes<CN>.A095::bool,
#            infoes<CN>.A096::bool,
#            infoes<CN>.A097::bool,
#            infoes<CN>.A098::bool,
#            infoes<CN>.A099::bool,
#            infoes<CN>.A100::bool,
#            infoes<CN>.A101::bool,
#            infoes<CN>.A102::bool,
#            infoes<CN>.A103::bool,
#            infoes<CN>.A104::bool,
#            infoes<CN>.A105::bool,
#            infoes<CN>.A106::bool,
#            infoes<CN>.A107::bool,
#            infoes<CN>.A108::bool,
#            infoes<CN>.A109::bool,
#            infoes<CN>.A110::bool,
#            infoes<CN>.A111::bool,
#            infoes<CN>.A112::bool,
#            infoes<CN>.A113::bool,
#            infoes<CN>.A114::bool,
#            infoes<CN>.A115::bool,
#            infoes<CN>.A116::bool,
#            infoes<CN>.A117::bool,
#            infoes<CN>.A118::bool,
#            infoes<CN>.A119::bool,
#            infoes<CN>.A120::bool,
#            infoes<CN>.A121::bool,
#            infoes<CN>.A122::bool,
#            infoes<CN>.A123::bool,
#            infoes<CN>.A124::bool,
#            infoes<CN>.A125::bool,
#            infoes<CN>.A126::bool,
#            infoes<CN>.A127::bool,
#            infoes<CN>.A128::bool,
#            infoes<CN>.A129::bool,
#            infoes<CN>.A130::bool,
#            infoes<CN>.A131::bool,
#            infoes<CN>.A132::bool,
#            infoes<CN>.A133::bool,
#            infoes<CN>.A134::bool,
#            infoes<CN>.A135::bool,
#            infoes<CN>.A136::bool,
#            infoes<CN>.A137::bool,
#            infoes<CN>.A138::bool,
#            infoes<CN>.A139::bool,
#            infoes<CN>.A140::bool,
#            infoes<CN>.A141::bool,
#            infoes<CN>.A142::bool,
#            infoes<CN>.A143::bool,
#            infoes<CN>.A144::bool,
#            infoes<CN>.A145::bool,
#            infoes<CN>.A146::bool,
#            infoes<CN>.A147::bool,
#            infoes<CN>.A148::bool,
#            infoes<CN>.A149::bool,
#            infoes<CN>.A150::bool,
#            infoes<CN>.A151::bool,
#            infoes<CN>.A152::bool,
#            infoes<CN>.A153::bool,
#            infoes<CN>.A154::bool,
#            infoes<CN>.A155::bool,
#            infoes<CN>.A156::bool,
#            infoes<CN>.A157::bool,
#            infoes<CN>.A158::bool,
#            infoes<CN>.A159::bool,
#            infoes<CN>.A160::bool,
#            infoes<CN>.A161::bool,
#            infoes<CN>.A162::bool,
#            infoes<CN>.A163::bool,
#            infoes<CN>.A164::bool,
#            infoes<CN>.A165::bool,
#            infoes<CN>.A166::bool,
#            infoes<CN>.A167::bool,
#            infoes<CN>.A168::bool,
#            infoes<CN>.A169::bool,
#            infoes<CN>.A170::bool,
#            infoes<CN>.A171::bool,
#            infoes<CN>.A172::bool,
#            infoes<CN>.A173::bool,
#            infoes<CN>.A174::bool,
#            infoes<CN>.A175::bool,
#            infoes<CN>.A176::bool,
#            infoes<CN>.A177::bool,
#            infoes<CN>.A178::bool,
#            infoes<CN>.A179::bool,
#            infoes<CN>.A180::bool,
#            infoes<CN>.A181::bool,
#            infoes<CN>.A182::bool,
#            infoes<CN>.A183::bool,
#            infoes<CN>.A184::bool,
#            infoes<CN>.A185::bool,
#            infoes<CN>.A186::bool,
#            infoes<CN>.A187::bool,
#            infoes<CN>.A188::bool,
#            infoes<CN>.A189::bool,
#            infoes<CN>.A190::bool,
#            infoes<CN>.A191::bool,
#            infoes<CN>.A192::bool,
#            infoes<CN>.A193::bool,
#            infoes<CN>.A194::bool,
#            infoes<CN>.A195::bool,
#            infoes<CN>.A196::bool,
#            infoes<CN>.A197::bool,
#            infoes<CN>.A198::bool,
#            infoes<CN>.A199::bool,
#            infoes<CN>.A200::bool,
#            infoes<CN>.A201::bool,
#            infoes<CN>.A202::bool,
#            infoes<CN>.A203::bool,
#            infoes<CN>.A204::bool,
#            infoes<CN>.A205::bool,
#            infoes<CN>.A206::bool,
#            infoes<CN>.A207::bool,
#            infoes<CN>.A208::bool,
#            infoes<CN>.A209::bool,
#            infoes<CN>.A210::bool,
#            infoes<CN>.A211::bool,
#            infoes<CN>.A212::bool,
#            infoes<CN>.A213::bool,
#            infoes<CN>.A214::bool,
#            infoes<CN>.A215::bool,
#            infoes<CN>.A216::bool,
#            infoes<CN>.A217::bool,
#            infoes<CN>.A218::bool,
#            infoes<CN>.A219::bool,
#            infoes<CN>.A220::bool,
#            infoes<CN>.A221::bool,
#            infoes<CN>.A222::bool,
#            infoes<CN>.A223::bool,
#            infoes<CN>.A224::bool,
#            infoes<CN>.A225::bool,
#            infoes<CN>.A226::bool,
#            infoes<CN>.A227::bool,
#            infoes<CN>.A228::bool,
#            infoes<CN>.A229::bool,
#            infoes<CN>.A230::bool,
#            infoes<CN>.A231::bool,
#            infoes<CN>.A232::bool,
#            infoes<CN>.A233::bool,
#            infoes<CN>.A234::bool,
#            infoes<CN>.A235::bool,
#            infoes<CN>.A236::bool,
#            infoes<CN>.A237::bool,
#            infoes<CN>.A238::bool,
#            infoes<CN>.A239::bool,
#            infoes<CN>.A240::bool,
#            infoes<CN>.A241::bool,
#            infoes<CN>.A242::bool,
#            infoes<CN>.A243::bool,
#            infoes<CN>.A244::bool,
#            infoes<CN>.A245::bool,
#            infoes<CN>.A246::bool,
#            infoes<CN>.A247::bool,
#            infoes<CN>.A248::bool,
#            infoes<CN>.A249::bool,
#            infoes<CN>.A250::bool,
#            infoes<CN>.A251::bool,
#            infoes<CN>.A252::bool,
#            infoes<CN>.A253::bool,
#            infoes<CN>.A254::bool,
#            infoes<CN>.A255::bool,
#            infoes<CN>.A256::bool,
#            infoes<CN>.A257::bool,
#            infoes<CN>.A258::bool,
#            infoes<CN>.A259::bool,
#            infoes<CN>.A260::bool,
#            infoes<CN>.A261::bool,
#            infoes<CN>.A262::bool,
#            infoes<CN>.A263::bool,
#            infoes<CN>.A264::bool,
#            infoes<CN>.A265::bool,
#            infoes<CN>.A266::bool,
#            infoes<CN>.A267::bool,
#            infoes<CN>.A268::bool,
#            infoes<CN>.A269::bool,
#            infoes<CN>.A270::bool,
#            infoes<CN>.asof_date::datetime64[ns],
#            infoes<CN>.上市日期::datetime64[ns],
#            infoes<CN>.国证一级行业::object,
#            infoes<CN>.国证一级行业编码::object,
#            infoes<CN>.国证三级行业::object,
#            infoes<CN>.国证三级行业编码::object,
#            infoes<CN>.国证二级行业::object,
#            infoes<CN>.国证二级行业编码::object,
#            infoes<CN>.国证四级行业::object,
#            infoes<CN>.国证四级行业编码::object,
#            infoes<CN>.城市::object,
#            infoes<CN>.市场::object,
#            infoes<CN>.注册资本::float64,
#            infoes<CN>.注册资本十分位数::int64,
#            infoes<CN>.状态::object,
#            infoes<CN>.申万一级行业::object,
#            infoes<CN>.申万三级行业::object,
#            infoes<CN>.申万二级行业::object,
#            infoes<CN>.省份::object,
#            infoes<CN>.股票简称::object,
#            infoes<CN>.证监会一级行业::object,
#            infoes<CN>.证监会二级行业::object,
#            infoes<CN>.超级部门::object,
#            infoes<CN>.部门::object})

# %% [markdown]
# # 注册资本

# %%
def make_pipeline():
    return Pipeline(columns={
        '注册资本': Fundamentals.info.注册资本.latest,
        '注册资本十分位数': Fundamentals.info.注册资本十分位数.latest,
    })

data_output = run_pipeline(
    make_pipeline(),
    start_date='2018-01-10',
    end_date='2018-01-10'
)

data_output.tail()
# Out:
#                                                 注册资本  注册资本十分位数
# 2018-01-10 00:00:00+00:00 洛阳钼业(603993)  4.319848e+09         9
#                           中新科技(603996)  3.001500e+08         2
#                           继峰股份(603997)  6.396490e+08         5
#                           方盛制药(603998)  4.285627e+08         3
#                           读者传媒(603999)  5.760000e+08         4

# %% [markdown]
# # 部门及超级部门

# %%
def make_pipeline():
    return Pipeline(columns={
        '部门': Fundamentals.info.部门.latest,
        '超级部门': Fundamentals.info.超级部门.latest,
    })

data_output = run_pipeline(
    make_pipeline(),
    start_date='2018-01-10',
    end_date='2018-01-10'
)

data_output.tail()
# Out:
#                                           部门 超级部门
# 2018-01-10 00:00:00+00:00 洛阳钼业(603993)  基本材料   周期
#                           中新科技(603996)  可选消费   防御
#                           继峰股份(603997)  可选消费   防御
#                           方盛制药(603998)  医疗保健   防御
#                           读者传媒(603999)  可选消费   防御

# %% [markdown]
# # 上市日期

# %%
def make_pipeline():
    return Pipeline(columns={
        '上市日期': Fundamentals.info.上市日期.latest,
    })

data_output = run_pipeline(
    make_pipeline(),
    start_date='2018-01-01',
    end_date='2018-01-10'
)

data_output.xs(symbol(600645), level=1)
# Out:
#                                 上市日期
# 2018-01-02 00:00:00+00:00 1993-05-04
# 2018-01-03 00:00:00+00:00 1993-05-04
# 2018-01-04 00:00:00+00:00 1993-05-04
# 2018-01-05 00:00:00+00:00 1993-05-04
# 2018-01-08 00:00:00+00:00 1993-05-04
# 2018-01-09 00:00:00+00:00 1993-05-04
# 2018-01-10 00:00:00+00:00 1993-05-04

# %% [markdown]
# # 行业分类
#
# 行业分类静态化，数据为最新行业分类。

# %% [markdown]
# ## 证监会行业分类

# %%
def make_pipeline():
    return Pipeline(columns={
        '证监会一级行业': Fundamentals.info.证监会一级行业.latest,
        '证监会二级行业': Fundamentals.info.证监会二级行业.latest,
    })

data_output = run_pipeline(
    make_pipeline(),
    start_date='2018-01-10',
    end_date='2018-01-10'
)

data_output.tail()
# Out:
#                                           证监会一级行业           证监会二级行业
# 2018-01-10 00:00:00+00:00 洛阳钼业(603993)        采矿业          有色金属矿采选业
#                           中新科技(603996)        制造业  计算机、通信和其他电子设备制造业
#                           继峰股份(603997)        制造业             汽车制造业
#                           方盛制药(603998)        制造业             医药制造业
#                           读者传媒(603999)  文化、体育和娱乐业            新闻和出版业

# %% [markdown]
# ## 申万行业分类

# %%
def make_pipeline():
    return Pipeline(columns={
        '申万一级行业': Fundamentals.info.申万一级行业.latest,
        '申万二级行业': Fundamentals.info.申万二级行业.latest,
        '申万三级行业': Fundamentals.info.申万三级行业.latest,
    })

data_output = run_pipeline(
    make_pipeline(),
    start_date='2018-01-10',
    end_date='2018-01-10'
)

data_output.tail()
# Out:
#                                        申万一级行业 申万二级行业   申万三级行业
# 2018-01-10 00:00:00+00:00 洛阳钼业(603993)   有色金属   稀有金属  其他稀有小金属
#                           中新科技(603996)   家用电器   视听器材       彩电
#                           继峰股份(603997)     汽车  汽车零部件    汽车零部件
#                           方盛制药(603998)   医药生物     中药       中药
#                           读者传媒(603999)     传媒   文化传媒     平面媒体

# %% [markdown]
# ## 国证行业分类

# %%
def make_pipeline():
    return Pipeline(columns={
        '国证一级行业': Fundamentals.info.国证一级行业.latest,
        '国证二级行业': Fundamentals.info.国证二级行业.latest,
        '国证三级行业': Fundamentals.info.国证三级行业.latest,
        '国证四级行业': Fundamentals.info.国证四级行业.latest,
    })

data_output = run_pipeline(
    make_pipeline(),
    start_date='2018-01-10',
    end_date='2018-01-10'
)

data_output.tail()
# Out:
#                                        国证一级行业    国证二级行业    国证三级行业 国证四级行业
# 2018-01-10 00:00:00+00:00 洛阳钼业(603993)    原材料      基础材料      有色金属   稀有金属
#                           中新科技(603996)   可选消费     耐用消费品      家用电器   视听器材
#                           继峰股份(603997)   可选消费  汽车与汽车零配件  汽车零配件与设备  汽车零配件
#                           方盛制药(603998)   医药卫生        制药      化学制剂   化学制剂
#                           读者传媒(603999)   可选消费        传媒        传媒     出版

# %% [markdown]
# # 地区分类

# %%
def make_pipeline():
    return Pipeline(columns={
        '省份': Fundamentals.info.省份.latest,
        '城市': Fundamentals.info.城市.latest,
    })

data_output = run_pipeline(
    make_pipeline(),
    start_date='2018-01-10',
    end_date='2018-01-10'
)

data_output.tail()
# Out:
#                                         省份   城市
# 2018-01-10 00:00:00+00:00 洛阳钼业(603993)  河南  洛阳市
#                           中新科技(603996)  浙江  台州市
#                           继峰股份(603997)  浙江  宁波市
#                           方盛制药(603998)  湖南  长沙市
#                           读者传媒(603999)  甘肃  兰州市

# %% [markdown]
# # 股票概念

# %% [markdown]
# ## 映射表

# %%
Fundamentals.concept_maps
# Out:
# {'A001': 'H股',
#  'A002': 'QFII持股',
#  'A003': 'ST',
#  'A004': '5G概念',
#  'A005': 'IPO受益',
#  'A006': '上证50',
#  'A007': '上证180',
#  'A008': '中证100',
#  'A009': '沪深300',
#  'A010': '预亏预减',
#  'A011': '预盈预增',
#  'A012': '网络游戏',
#  'A013': '基金重仓',
#  'A014': '操盘手80',
#  'A015': '航天军工',
#  'A016': '节能环保',
#  'A017': '次新已开板',
#  'A018': '新材料概念',
#  'A019': '深证100',
#  'A020': '整体上市',
#  'A021': '高价',
#  'A022': '中价',
#  'A023': '低价',
#  'A024': '参股金融',
#  'A025': '大盘',
#  'A026': '中盘',
#  'A027': '小盘',
#  'A028': '券商重仓',
#  'A029': '社保重仓',
#  'A030': '振兴东北',
#  'A031': '未股改',
#  'A032': '稀缺资源',
#  'A033': '创投概念',
#  'A034': '基金增仓',
#  'A035': '深成500',
#  'A036': '基金新增',
#  'A037': '大订单',
#  'A038': '成渝特区',
#  'A039': '低市净率',
#  'A040': '高送转',
#  'A041': '股权激励',
#  'A042': '定向增发',
#  'A043': '高铁',
#  'A044': '核电核能',
#  'A045': '迪士尼',
#  'A046': '财政扶持',
#  'A047': '物联网',
#  'A048': '稀土永磁',
#  'A049': '锂电池',
#  'A050': '云计算',
#  'A051': '增持回购',
#  'A052': '太阳能',
#  'A053': '西部开发',
#  'A054': '黄金概念',
#  'A055': '智能电网',
#  'A056': '明星基金',
#  'A057': '电子商务',
#  'A058': '上证380',
#  'A059': '新能源汽车',
#  'A060': 'LED',
#  'A061': '融资融券',
#  'A062': '参股新三板',
#  'A063': '水利',
#  'A064': '风能',
#  'A065': '涉矿概念',
#  'A066': '金融改革',
#  'A067': '央视50',
#  'A068': '页岩气',
#  'A069': '三沙概念',
#  'A070': '3D打印',
#  'A071': '地热能',
#  'A072': '食品医药安全',
#  'A073': '摘帽',
#  'A074': '芯片',
#  'A075': 'TMT概念',
#  'A076': '重组并购',
#  'A077': '美丽中国',
#  'A078': '智慧城市',
#  'A079': '风险警示板',
#  'A080': '智能手机',
#  'A081': '三网融合',
#  'A082': '北斗导航',
#  'A083': '农业机械',
#  'A084': '煤化工',
#  'A085': '特色化工',
#  'A086': '大飞机',
#  'A087': '通用航空',
#  'A088': '海洋工程',
#  'A089': '智能制造',
#  'A090': '特种药',
#  'A091': '转融通',
#  'A092': '海西概念',
#  'A093': 'PM2.5',
#  'A094': '转融券',
#  'A095': '举牌',
#  'A096': '人脑工程',
#  'A097': '抗病毒',
#  'A098': '地理信息',
#  'A099': '智能穿戴',
#  'A100': '大数据',
#  'A101': '上海自贸区',
#  'A102': '宽带中国',
#  'A103': '海洋经济',
#  'A104': '土地流转',
#  'A105': '王亚伟概念',
#  'A106': '养老概念',
#  'A107': '天津自贸区',
#  'A108': '海绵城市',
#  'A109': '油改概念',
#  'A110': '广东自贸区',
#  'A111': '婴童概念',
#  'A112': '生态农业',
#  'A113': '国家安全',
#  'A114': '广东国资整合',
#  'A115': '上海国资整合',
#  'A116': '浙江自贸区',
#  'A117': '重庆自贸区',
#  'A118': '蓝宝石',
#  'A119': '福建自贸区',
#  'A120': '无人驾驶',
#  'A121': '体育概念',
#  'A122': '民营医院',
#  'A123': '电力改革',
#  'A124': '燃料电池',
#  'A125': '京津冀',
#  'A126': '中俄自贸区',
#  'A127': '天津国资整合',
#  'A128': '湖南国资整合',
#  'A129': '安徽自贸区',
#  'A130': 'AH股',
#  'A131': '黄河金三角',
#  'A132': '博彩概念',
#  'A133': '国资委整合',
#  'A134': '地方国资整合',
#  'A135': '生猪概念',
#  'A136': '天然气概念',
#  'A137': '去IOE概念',
#  'A138': '高校概念',
#  'A139': '量子通信',
#  'A140': '中韩自贸区',
#  'A141': '盐改概念',
#  'A142': '沪股通',
#  'A143': '精准医疗',
#  'A144': '超级电容',
#  'A145': '石墨烯',
#  'A146': '手机游戏',
#  'A147': '在线教育',
#  'A148': '电子支付',
#  'A149': '无人机',
#  'A150': '充电桩',
#  'A151': '一带一路',
#  'A152': '乡村振兴',
#  'A153': '杠杆B类基金',
#  'A154': '中字头',
#  'A155': '内陆自贸区',
#  'A156': '中证500',
#  'A157': '沪台通',
#  'A158': '储能概念',
#  'A159': 'PPP概念',
#  'A160': '证金持股',
#  'A161': '汇金持股',
#  'A162': '员工持股',
#  'A163': '破净股',
#  'A164': '健康中国',
#  'A165': '能源互联网',
#  'A166': '东盟自贸区',
#  'A167': '虚拟现实',
#  'A168': '维生素',
#  'A169': '壳资源',
#  'A170': '外汇局持股',
#  'A171': '债转股',
#  'A172': '电子竞技',
#  'A173': '网红经济',
#  'A174': '深股通',
#  'A175': '生物识别',
#  'A176': 'AR概念',
#  'A177': '参股恒大',
#  'A178': '中概股回归',
#  'A179': '股权转让',
#  'A180': '昨日涨停',
#  'A181': '混改',
#  'A182': '共享经济',
#  'A183': '小金属',
#  'A184': '辽宁自贸区',
#  'A185': '雄安新区',
#  'A186': '粤港澳大湾区',
#  'A187': '地下管廊',
#  'A188': '卓越70',
#  'A189': '可燃冰',
#  'A190': '特色小镇',
#  'A191': 'MSCI中国',
#  'A192': '租售同权',
#  'A193': '养老金持股',
#  'A194': '乙醇汽油',
#  'A195': '盐湖提锂',
#  'A196': '阿里概念',
#  'A197': '自由贸易港',
#  'A198': '供给侧改革',
#  'A199': '装配式建筑',
#  'A200': '腾讯概念',
#  'A201': '富士康概念',
#  'A202': '工业互联网',
#  'A203': '独角兽概念',
#  'A204': '小米概念',
#  'A205': '知识产权保护',
#  'A206': '数字中国',
#  'A207': '仿制药',
#  'A208': '海南自贸区',
#  'A209': '成泉资本',
#  'A210': '短视频',
#  'A211': '华为概念',
#  'A212': '百度概念',
#  'A213': '人民币贬值',
#  'A214': '创业板50',
#  'A215': '超跌概念',
#  'A216': '高质押概念',
#  'A217': '国资驰援',
#  'A218': '昨曾涨停',
#  'A219': '科创板概念',
#  'A220': '人民币升值',
#  'A221': '芬太尼',
#  'A222': '长三角一体化',
#  'A223': '建筑节能',
#  'A224': '云计算软件',
#  'A225': '云计算集成',
#  'A226': '云计算硬件',
#  'A227': '特高压',
#  'A228': '苹果概念',
#  'A229': '抗癌药',
#  'A230': '抗艾滋',
#  'A231': '义乌金改',
#  'A232': '节能',
#  'A233': '机器人',
#  'A234': '互联网金融',
#  'A235': '安防',
#  'A236': '滨海旅游',
#  'A237': '电子发票',
#  'A238': '智能家居',
#  'A239': '土地改革',
#  'A240': '电子烟',
#  'A241': 'P2P网贷',
#  'A242': 'O2O',
#  'A243': '儿童教育',
#  'A244': '绿色食品',
#  'A245': '网络安全',
#  'A246': '环保检测',
#  'A247': '冬奥概念',
#  'A248': '特斯拉',
#  'A249': '糖尿病',
#  'A250': '深圳国资整合',
#  'A251': '医药电商',
#  'A252': '埃博拉',
#  'A253': '股东增持',
#  'A254': '高管增持',
#  'A255': '深圳前海',
#  'A256': '广州南沙',
#  'A257': '珠海横琴',
#  'A258': '智能医疗',
#  'A259': '电子政务',
#  'A260': '工业4.0',
#  'A261': '全息手机概念',
#  'A262': '宝能系',
#  'A263': '人工智能',
#  'A264': 'OLED',
#  'A265': '区块链',
#  'A266': '万达私有化',
#  'A267': '蚂蚁金服',
#  'A268': '光通信',
#  'A269': '共享单车',
#  'A270': '共享汽车'}

# %% [markdown]
# ## 查询概念名称

# %%
Fundamentals.concept_col_name('A270')
# Out:
# '共享汽车'

# %% [markdown]
# ## 查询概念编码

# %%
Fundamentals.concept_col_code('汽车')
# Out:
# {'A059': '新能源汽车', 'A270': '共享汽车'}

# %%
def make_pipeline():
    return Pipeline(columns={
        '共享汽车': Fundamentals.info.A270.latest,
#         '人工智能': Fundamentals.info.A263.latest,
    })

data_output = run_pipeline(
    make_pipeline(),
    start_date='2018-01-10',
    end_date='2018-01-10'
)

data_output[data_output['共享汽车']]
# Out:
#                                         共享汽车
# 2018-01-10 00:00:00+00:00 海马汽车(000572)  True
#                           青岛双星(000599)  True
#                           长安汽车(000625)  True
#                           一汽轿车(000800)  True
#                           得润电子(002055)  True
#                           大洋电机(002249)  True
#                           兆新股份(002256)  True
#                           中电兴发(002298)  True
#                           英威腾(002334)   True
#                           多氟多(002407)   True
#                           万安科技(002590)  True
#                           宜昌交运(002627)  True
#                           合康新能(300048)  True
#                           纳川股份(300198)  True
#                           欣旺达(300207)   True
#                           上汽集团(600104)  True
#                           强生控股(600662)  True
#                           小康股份(601127)  True
#                           庞大集团(601258)  True
#                           骆驼股份(601311)  True
#                           力帆股份(601777)  True
#                           隆鑫通用(603766)  True
#                           永安行(603776)   True

# %% [markdown]
# # 上市状态

# %%
def make_pipeline():
    return Pipeline(columns={
        '状态': Fundamentals.info.状态.latest,
    })

data_output = run_pipeline(
    make_pipeline(),
    start_date='2018-01-10',
    end_date='2018-01-10'
)

data_output.tail()
# Out:
#                                           状态
# 2018-01-10 00:00:00+00:00 洛阳钼业(603993)  正常上市
#                           中新科技(603996)  正常上市
#                           继峰股份(603997)  正常上市
#                           方盛制药(603998)  正常上市
#                           读者传媒(603999)  正常上市
