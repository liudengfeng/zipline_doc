# %%
import cufflinks as cf

# %%
df=cf.datagen.ohlcv()

# %% [raw]
# qf=cf.QuantFig(df,title='First Quant Figure',legend='top',name='GS')
# qf.add_bollinger_bands()
# qf.iplot()

# %%
ohlc = df.drop(columns=['volume'])

# %%
ohlc.plot();

# %%
ohlc.tail(6)
# Out:
#                   open        high         low       close
# 2015-04-05  201.530699  218.844561  192.438447  209.794707
# 2015-04-06  209.765646  211.847051  176.773447  181.501580
# 2015-04-07  182.163334  189.808323  166.788993  169.850200
# 2015-04-08  170.133604  183.659437  164.190273  173.814825
# 2015-04-09  174.751099  195.647982  168.401682  184.323916
# 2015-04-10  184.776219  212.226897  183.835906  197.857476
