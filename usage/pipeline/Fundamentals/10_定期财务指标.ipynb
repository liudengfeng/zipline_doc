# %%
from zipline.pipeline import Pipeline
from zipline.research import run_pipeline, symbols, symbol, select_output_by
from zipline.pipeline.fundamentals import Fundamentals

# %%
def make_pipeline():
    return Pipeline(
        columns={
            '净资产比率': Fundamentals.financial_indicators.净资产比率.latest,
            '应收账款周转率': Fundamentals.financial_indicators.应收账款周转率.latest,
        })


data_output = run_pipeline(
    make_pipeline(), start_date='2015-06-01', end_date='2016-06-10')

# %%
select_output_by(data_output, assets=['000333', '600645','002024'])
# Out:
#                                          净资产比率  应收账款周转率
# 2015-06-01 00:00:00+00:00 美的集团(000333)     NaN      NaN
#                           苏宁易购(002024)  34.568   38.301
#                           中源协和(600645)     NaN      NaN
# 2015-06-02 00:00:00+00:00 美的集团(000333)     NaN      NaN
#                           苏宁易购(002024)  34.568   38.301
#                           中源协和(600645)     NaN      NaN
# 2015-06-03 00:00:00+00:00 美的集团(000333)     NaN      NaN
#                           苏宁易购(002024)  34.568   38.301
#                           中源协和(600645)     NaN      NaN
# 2015-06-04 00:00:00+00:00 美的集团(000333)     NaN      NaN
#                           苏宁易购(002024)  34.568   38.301
#                           中源协和(600645)     NaN      NaN
# 2015-06-05 00:00:00+00:00 美的集团(000333)     NaN      NaN
#                           苏宁易购(002024)  34.568   38.301
#                           中源协和(600645)     NaN      NaN
# 2015-06-08 00:00:00+00:00 美的集团(000333)     NaN      NaN
#                           苏宁易购(002024)  34.568   38.301
#                           中源协和(600645)     NaN      NaN
# 2015-06-09 00:00:00+00:00 美的集团(000333)     NaN      NaN
#                           苏宁易购(002024)  34.568   38.301
#                           中源协和(600645)     NaN      NaN
# 2015-06-10 00:00:00+00:00 美的集团(000333)     NaN      NaN
#                           苏宁易购(002024)  34.568   38.301
#                           中源协和(600645)     NaN      NaN
# 2015-06-11 00:00:00+00:00 美的集团(000333)     NaN      NaN
#                           苏宁易购(002024)  34.568   38.301
#                           中源协和(600645)     NaN      NaN
# 2015-06-12 00:00:00+00:00 美的集团(000333)     NaN      NaN
#                           苏宁易购(002024)  34.568   38.301
#                           中源协和(600645)     NaN      NaN
# ...                                        ...      ...
# 2016-05-26 00:00:00+00:00 美的集团(000333)     NaN      NaN
#                           苏宁易购(002024)  32.708   44.489
#                           中源协和(600645)     NaN      NaN
# 2016-05-27 00:00:00+00:00 美的集团(000333)     NaN      NaN
#                           苏宁易购(002024)  32.708   44.489
#                           中源协和(600645)     NaN      NaN
# 2016-05-30 00:00:00+00:00 美的集团(000333)     NaN      NaN
#                           苏宁易购(002024)  32.708   44.489
#                           中源协和(600645)     NaN      NaN
# 2016-05-31 00:00:00+00:00 美的集团(000333)     NaN      NaN
#                           苏宁易购(002024)  32.708   44.489
#                           中源协和(600645)     NaN      NaN
# 2016-06-01 00:00:00+00:00 美的集团(000333)     NaN      NaN
#                           苏宁易购(002024)  32.708   44.489
#                           中源协和(600645)     NaN      NaN
# 2016-06-02 00:00:00+00:00 美的集团(000333)     NaN      NaN
#                           苏宁易购(002024)  32.708   44.489
#                           中源协和(600645)     NaN      NaN
# 2016-06-03 00:00:00+00:00 美的集团(000333)     NaN      NaN
#                           苏宁易购(002024)  32.708   44.489
#                           中源协和(600645)     NaN      NaN
# 2016-06-06 00:00:00+00:00 美的集团(000333)     NaN      NaN
#                           苏宁易购(002024)  32.708   44.489
#                           中源协和(600645)     NaN      NaN
# 2016-06-07 00:00:00+00:00 美的集团(000333)     NaN      NaN
#                           苏宁易购(002024)  32.708   44.489
#                           中源协和(600645)     NaN      NaN
# 2016-06-08 00:00:00+00:00 美的集团(000333)     NaN      NaN
#                           苏宁易购(002024)  32.708   44.489
#                           中源协和(600645)     NaN      NaN
#
# [756 rows x 2 columns]
